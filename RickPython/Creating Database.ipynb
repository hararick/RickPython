# %%
# !pip install pymysql

# %%
import pymysql

# %%
conn =pymysql.connect(host="localhost", port=3306, user="root", password="musaeesa", db="sys")

# %%
cursor = conn.cursor()

# %%
cursor.execute("CREATE DATABASE testdb;")
# Out:
# 1

# %%
cursor.execute("SHOW DATABASES;")
# Out:
# 5

# %%
cursor.fetchone(), cursor.fetchmany(10), cursor.fetchall(), list(cursor)
# Out:
# (None, (), [], [])

# %%
cursor.fetchall()
# Out:
# ()

# %%
cursor.fetchall()
# Out:
# ()

# %%
cursor.execute("CREATE DATABASE school;")
# Out:
# 1

# %%
cursor.execute("SHOW DATABASES;")
# Out:
# 6

# %%
cursor.fetchall()
# Out:
# (('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('school',),
#  ('sys',),
#  ('testdb',))

# %%
cursor.execute("DROP DATABASE testdb;")
# Out:
# 0

# %%
cursor.execute("SHOW DATABASES;")
cursor.fetchall()
# Out:
# (('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('school',),
#  ('sys',))

# %%
conn.close()
